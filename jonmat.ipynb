# %%
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
api_keys = json.load(open('api_keys.json', 'r'))

# %% [markdown]
# # 1. 주소 있는 데이터 읽어서 확인

# %%
df = pd.read_csv('./jonmat2017.csv')
df = df[df.columns[:-1]]

# %%
df = df[~df.주소.isnull()]
df[:3]
# Out:
#            총연번  의원번호  의원명      당  당ID              지역명        연월일  \
# 345  17_001545     5  강석호  자유한국당  200  경북 영양군영덕군봉화군울진군  2017.1.11
# 346  17_001554     5  강석호  자유한국당  200  경북 영양군영덕군봉화군울진군  2017.1.17
# 347  17_001556     5  강석호  자유한국당  200  경북 영양군영덕군봉화군울진군  2017.1.17
#
#                        내역      지출액     사용처        분류  \
# 345     지역현안관련정책개발보좌직원간담회  105,000  또래오래치킨   사무실_식대비
# 346  상임위법안소위관련보좌직원정책개발간담회  160,000      청도   사무실_식대비
# 347             정책개발기자간담회  350,000    잔비어스  언론_기자식대등
#
#                                      주소  의원지출액순위
# 345              서울특별시 영등포구 여의대방로68길 17        4
# 346  서울특별시 영등포구 여의도동 45-20 동북빌딩 203-204        4
# 347                   서울특별시 강남구 개포로 623        4

# %%
df['주소'] = df['주소'].apply(lambda x: x.strip() if type(x)==str else None)
df['지출액'] = df['지출액'].apply(lambda x: int(x.replace(',','')))

# %% [markdown]
# # 2. 주소 있는것 지오코딩

# %%
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key=api_keys['google_maps'])

# %%
def get_geocode(addr):
    geocode_result = gmaps.geocode(addr)
    if len(geocode_result) > 0:
        return geocode_result[0]['geometry']['location']
    else:
        return {'lat':0,'lng':0}

# %%
uniq = df['주소'].unique()

# %%
try:
    addr_dict = json.load(open('geocode_dict.json', 'r'))
except:
    addr_dict = {}

# %%
for addr in uniq:
    if addr in addr_dict:
        continue
    addr_dict[addr] = get_geocode(addr)

# %%
json.dump(addr_dict, open('geocode_dict.json', 'w'))

# %%
for enum in enumerate(addr_dict):
    if enum[0] > 2:
        break
    print(enum)
# Out:
# (0, '서울특별시 영등포구 여의대방로68길 17')
# (1, '서울특별시 영등포구 여의도동 45-20 동북빌딩 203-204')
# (2, '서울특별시 강남구 개포로 623')

# %%
df_latlng = df['주소'].apply(lambda x: pd.Series({f:addr_dict[x][f] for f in ['lat','lng']}))
df_latlng[:3]
# Out:
#            lat         lng
# 345  37.517729  126.932872
# 346  37.519623  126.928920
# 347  37.493935  127.079623

# %%
df = pd.concat([df, df_latlng], axis=1)

# %%
df[:3].T
# Out:
#                             345                                 346  \
# 총연번                   17_001545                           17_001554
# 의원번호                          5                                   5
# 의원명                         강석호                                 강석호
# 당                         자유한국당                               자유한국당
# 당ID                         200                                 200
# 지역명             경북 영양군영덕군봉화군울진군                     경북 영양군영덕군봉화군울진군
# 연월일                   2017.1.11                           2017.1.17
# 내역            지역현안관련정책개발보좌직원간담회                상임위법안소위관련보좌직원정책개발간담회
# 지출액                      105000                              160000
# 사용처                      또래오래치킨                                  청도
# 분류                      사무실_식대비                             사무실_식대비
# 주소       서울특별시 영등포구 여의대방로68길 17  서울특별시 영등포구 여의도동 45-20 동북빌딩 203-204
# 의원지출액순위                       4                                   4
# lat                     37.5177                             37.5196
# lng                     126.933                             126.929
#
#                        347
# 총연번              17_001556
# 의원번호                     5
# 의원명                    강석호
# 당                    자유한국당
# 당ID                    200
# 지역명        경북 영양군영덕군봉화군울진군
# 연월일              2017.1.17
# 내역               정책개발기자간담회
# 지출액                 350000
# 사용처                   잔비어스
# 분류                언론_기자식대등
# 주소       서울특별시 강남구 개포로 623
# 의원지출액순위                  4
# lat                37.4939
# lng                 127.08

# %% [markdown]
# # 3. 같은좌표의 다른 주소 표현
# (도로명, 건물명, 띄어쓰기 등)

# %%
def uniq_cnt(l):
    return len(l.unique())

# %%
addr_grouped = df.groupby(['사용처','lat','lng'])\
                .agg({'주소':[lambda x: len(x.unique()), min]})
addr_grouped[:3]
# Out:
#                                         주소
#                                   <lambda>                   min
# 사용처          lat       lng
# (주)거구상사      37.552459 126.937826        1      서울특별시 마포구 백범로 23
# (주)미가케이터링컴퍼니 37.519749 126.929719        1    서울특별시 영등포구 의사당대로 1
# (주)밥보        37.530234 126.921678        1  서욽특별시 영등포구 여의도동 13-3

# %%
addr_grouped.columns = ['uniq_cnt','addr']

# %%
addr_grouped = addr_grouped.query("uniq_cnt > 1").reset_index()
addr_grouped[:3]
# Out:
#               사용처        lat         lng  uniq_cnt                   addr
# 0  (주)이랜드파크켄싱턴여의도  37.530234  126.921678         2  서울특별시 영등포구 국회대로76길 16
# 1       (주)커피빈코리아  37.437736  126.786437         2  경기도 시흥시 산천로 100번안길 16
# 2           고래와새우  37.529955  126.919895         3  서울특별시 영등포구 국회대로 70길 7

# %%
def change_addr(series_place):
    print(df_all[df_all.사용처==series_place['사용처']])

# %%
addr_grouped[:3].apply(change_addr, axis=1)
# Out:
#              총연번  의원번호     의원명       당   당ID              지역명         연월일  \
# 404    17_001836     5     강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.6.15
# 2659   17_017916   355  김선동(서)   자유한국당   200          서울 도봉구을   2017.3.31
# 3773   17_022850    44     김영주  더불어민주당   100         서울 영등포구갑    2017.4.6
# 3937   17_024203    48     김용태   자유한국당   200          서울 양천구을    2017.3.5
# 4709   17_029024   372     김종회    국민의당  2050        전북 김제시부안군   2017.8.31
# 4736   17_029148   372     김종회    국민의당  2050        전북 김제시부안군  2017.10.18
# 6457   17_041186    97     민병두  더불어민주당   100         서울 동대문구을   2017.10.9
# 8658   17_057385   140     서청원   자유한국당   200          경기 화성시갑   2017.3.31
# 8688   17_057541   140     서청원   자유한국당   200          경기 화성시갑    2017.9.6
# 9521   17_062609   406     송영길  더불어민주당   100          인천 계양구을   2017.1.25
# 9524   17_062623   406     송영길  더불어민주당   100          인천 계양구을    2017.2.7
# 9550   17_062735   406     송영길  더불어민주당   100          인천 계양구을   2017.4.13
# 9564   17_062835   406     송영길  더불어민주당   100          인천 계양구을   2017.6.16
# 9568   17_062848   406     송영길  더불어민주당   100          인천 계양구을   2017.6.22
# 9570   17_062865   406     송영길  더불어민주당   100          인천 계양구을   2017.6.30
# 9573   17_062872   406     송영길  더불어민주당   100          인천 계양구을    2017.7.5
# 9575   17_062891   406     송영길  더불어민주당   100          인천 계양구을   2017.7.25
000  (주)이랜드파크켄싱턴여의도    간담회_식대
# 15641                 박의원공정위원장금융위원장조찬  170,000  (주)이랜드파크켄싱턴여의도    간담회_식대
# 15961                    국토교통위관련회의다과비   72,000  (주)이랜드파크켄싱턴여의도    간담회_다과
# 16962                       국회의원현안간담회   31,800  (주)이랜드파크켄싱턴여의도    간담회_식대
# 16967                     국정감사대비의원간담회   39,800  (주)이랜드파크켄싱턴여의도    간담회_식대
# 16968                     국정감사대비의원간담회   29,800  (주)이랜드파크켄싱턴여의도    간담회_식대
# 20602        탄핵정국대선대비당원외인사간담회(홍문종외2인)  184,400  (주)이랜드파크켄싱턴여의도    간담회_식대
#
#                           주소  의원지출액순위 Unnamed: 13
# 404     서울특별시 영등포구 여의도동 13-3        4         NaN
# 2659                     NaN       33         NaN
# 3773                     NaN       94         NaN
# 3937                     NaN      116         NaN
# 4709                     NaN       65         NaN
# 4736                     NaN       65         NaN
# 6457                     NaN       38         NaN
# 8658   서울특별시 영등포구 국회대로76길 16        5         NaN
# 8688   서울특별시 영등포구 국회대로76길 16        5         NaN
# 9521                     NaN       54         NaN
# 9524                     NaN       54         NaN
# 9550                     NaN       54         NaN
# 9564                     NaN       54         NaN
# 9568                     NaN       54         NaN
# 9570                     NaN       54         NaN
# 9573                     NaN       54         NaN
# 9575                     NaN       54         NaN
# 9578                     NaN       54         NaN
# 9582                     NaN       54         NaN
# 9584                     NaN       54         NaN
# 9593                     NaN       54         NaN
# 9595                     NaN       54         NaN
# 9600                     NaN       54         NaN
# 9601                     NaN       54         NaN
# 9605                     NaN       54         NaN
# 9606                     NaN       54         NaN
# 9610                     NaN       54         NaN
# 9698                     NaN      125         NaN
# 9720                     NaN      125         NaN
# 11488                    NaN       64         NaN
# 13700                    NaN       13         NaN
# 15641                    NaN       79         NaN
# 15961                    NaN       35         NaN
# 16962                    NaN       27         NaN
# 16967                    NaN       27         NaN
# 16968                    NaN       27         NaN
# 20602                    NaN      121         NaN
#              총연번  의원번호  의원명       당  당ID        지역명         연월일  \
# 703    17_004185   337  곽대훈   자유한국당  200    대구 달서구갑   2017.6.22
# 2754   17_018182   356  김성수  더불어민주당  100       비례대표   2017.3.24
# 2755   17_018183   356  김성수  더불어민주당  100       비례대표   2017.3.24
# 2917   17_018483   356  김성수  더불어민주당  100       비례대표   2017.11.8
# 10398  17_066801   164  안민석  더불어민주당  100     경기 오산시    2017.4.9
# 11396  17_074204   177  우원식  더불어민주당  100    서울 노원구을    2017.5.1
# 14869  17_097206   238  이종걸  더불어민주당  100  경기 안양시만안구   2017.3.19
# 14970  17_097518   238  이종걸  더불어민주당  100  경기 안양시만안구  2017.10.25
# 14973  17_097525   238  이종걸  더불어민주당  100  경기 안양시만안구  2017.10.28
# 14988  17_097554   238  이종걸  더불어민주당  100  경기 안양시만안구   2017.11.8
# 17837  17_116044   467  제윤경  더불어민주당  100       비례대표   2017.2.11
# 17929  17_116251   467  제윤경  더불어민주당  100       비례대표    2017.5.8
# 17930  17_116252   467  제윤경  더불어민주당  100       비례대표    2017.5.8
# 17993  17_116415   467  제윤경  더불어민주당  100       비례대표   2017.7.25
# 19809  17_125558   481  최운열  더불어민주당  100       비례대표    2017.7.7
#
# 14321                          기자간담회   110,000  고래와새우  언론_기자식대등
# 14368                     환노위출입기자간담회   170,000  고래와새우  언론_기자식대등
# 14545                     환경정책전문가간담회   111,700  고래와새우    간담회_식대
# 15314                        국회의원간담회   119,700  고래와새우    간담회_식대
# 15402                        국회의원간담회   105,000  고래와새우    간담회_식대
# 15479                      국회의원간담회식대   155,000  고래와새우    간담회_식대
# 16900                매일경제기자초청경제현안간담회   150,000  고래와새우  언론_기자식대등
# 16922                 국민일보국회출입기자단간담회   317,000  고래와새우  언론_기자식대등
# 16936         뉴스1,머니투데이등경제지국회출입기자간담회   269,000  고래와새우  언론_기자식대등
# 16973                    헤럴드경제기자단간담회   178,000  고래와새우  언론_기자식대등
# 16986                   내일신문기자단현안간담회   195,000  고래와새우  언론_기자식대등
# 17209                     정책협의관련간담회비   275,000  고래와새우    간담회_식대
# 17536                 성평등추진체계관련전문가면담    40,000  고래와새우    간담회_식대
# 17538   복지위출입기자간담회(한겨레등총3명참석/국민건강보험법    80,000  고래와새우  언론_기자식대등
# 17550                 정무위위원현안교류오찬간담회    55,000  고래와새우    간담회_식대
# 17562       현안교류의원간담회(국토위교문위위원총3명참석)    94,800  고래와새우    간담회_식대
# 17586  복지위출입기자간담회(TV조선등총6명참석/장애인활동지원   180,000  고래와새우  언론_기자식대등
# 17593   국회출입여성기자간담회(KBS등총4명참석/결혼중개업의   120,000  고래와새우  언론_기자식대등
# 17619   국회출입기자간담회(오아이뉴스등총5명참석/치매관리법등   140,000  고래와새우  언론_기자식대등
# 17634                     정책개발비(간담회)    30,800  고래와새우    간담회_식대
# 18001                    당내현안관련기자간담회   150,000  고래와새우  언론_기자식대등
# 18032                    당내현안관련기자간담회    80,000  고래와새우  언론_기자식대등
# 20249    정기국회대정부질의내용관련간담회(신당사무총장외3인)   151,000  고래와새우    간담회_식대
# 20273               파이로전문가검증단구성관련간담회   361,500  고래와새우    간담회_식대
#
#                               주소  의원지출액순위 Unnamed: 13
# 221                          NaN       55         NaN
# 224                          NaN       55         NaN
# 278                          NaN       55         NaN
# 614                          NaN      111         NaN
# 618                          NaN      111         NaN
# 619                          NaN      111         NaN
# 625                          NaN      111         NaN
# 631                          NaN      111         NaN
# 633                          NaN      111         NaN
# 634                          NaN      111         NaN
# 636                          NaN      111         NaN
# 639                          NaN      111         NaN
# 642                          NaN      111         NaN
# 677                          NaN      193         NaN
# 1006                         NaN       24         NaN
# 1505                         NaN       22         NaN
# 1529                         NaN       22         NaN
# 1530                         NaN       22         NaN
# 1531                         NaN       22         NaN
# 1532                         NaN       22         NaN
# 1559                         NaN       22         NaN
# 1594                         NaN       22         NaN
# 2684                         NaN       33         NaN
# 2726   서울특별시 영등포구 여의도동 14-2 동아빌딩        6         NaN
# 3379                         NaN       78         NaN
# 3676                         NaN      110         NaN
# 3868                         NaN      129         NaN
# 3935                         NaN      116         NaN
# 4199                         NaN       76         NaN
# 4398                         NaN       30         NaN
# ...                          ...      ...         ...
# 11762                        NaN      122         NaN
# 11768                        NaN      122         NaN
# 11771                        NaN      122         NaN
# 13843                        NaN       13         NaN
# 14011                        NaN       36         NaN
# 14183                        NaN      214         NaN
# 14321                        NaN       44         NaN
# 14368                        NaN       44         NaN
# 14545                        NaN       44         NaN
# 15314                        NaN        7         NaN
# 15402                        NaN        7         NaN
# 15479                        NaN        7         NaN
# 16900                        NaN       27         NaN
# 16922                        NaN       27         NaN
# 16936                        NaN       27         NaN
# 16973                        NaN       27         NaN
# 16986                        NaN       27         NaN
# 17209       서울특별시 영등포구 여의도동 14-2        1         NaN
# 17536                        NaN       46         NaN
# 17538                        NaN       46         NaN
# 17550                        NaN       46         NaN
# 17562                        NaN       46         NaN
# 17586                        NaN       46         NaN
# 17593                        NaN       46         NaN
# 17619                        NaN       46         NaN
# 17634                        NaN       29         NaN
# 18001                        NaN       11         NaN
# 18032                        NaN       11         NaN
# 20249                        NaN       82         NaN
# 20273                        NaN       82         NaN
#
# [100 rows x 14 columns]
# 0    None
# 1    None
# 2    None
# dtype: object

# %% [markdown]
# # 기타(정리 안 함)

# %%
import requests
import json

# %%
df_all = pd.read_csv('jonmat2017.csv')
place_dict = {}

# %%
import requests
import json
import time

class NaverMaps():
    headers = {}
    url_format = "https://naveropenapi.apigw.ntruss.com/map-place/v1/"+\
        "search?query=%s&coordinate=126.929719,37.519749"
    
    def __init__(self, api_key_id, api_key):
        self.headers = {"X-NCP-APIGW-API-KEY-ID":api_key_id,
                        "X-NCP-APIGW-API-KEY":api_key,
                    }
    
    def search(self, query_string, retry=5):
        query_string = query_string.replace('#','')
        r = requests.get(self.url_format % query_string, headers=self.headers)
        d = json.loads(r.text)
        if d['status'] != 'OK':
            if retry > 0:
                print("%s retry: %s" % (place_name, retry))
                time.sleep(3)
                return self.search(query_string, retry=retry-1)
            else:
                raise BaseException(query_string, d)
        return d

# %%
m = NaverMaps(api_keys['naver_maps_id'], api_keys['naver_maps_key'])
r = m.search('비야게레로')
r
# Out:
# {'status': 'OK',
#  'meta': {'totalCount': 1, 'count': 1},
#  'places': [{'name': '비야게레로',
#    'road_address': '서울특별시 강남구 봉은사로78길 12',
#    'jibun_address': '서울특별시 강남구 삼성동 118-21 101호',
#    'phone_number': '02-538-8915',
#    'x': '127.0528107',
#    'y': '37.5119717',
#    'distance': 10883.506983308978,
#    'sessionId': 'C8AqpmkBLhmWpuc1KvlZ'}],
#  'errorMessage': ''}

# %%
for place_name in df['사용처'].unique():
    if place_name not in place_dict:
        #print("requested")
        r = m.search(place_name)
        place_dict[place_name] = r['places']
    #print(place_name, len(place_dict[place_name]))
# Out:
# (주)파리크라상천등산(평택방향) retry: 5
# (주)파리크라상천등산(평택방향) retry: 4
# 친구찾기 retry: 5
# 친구찾기 retry: 4
# 우동전문점 retry: 5
# 신안홍탁 retry: 5
# (주)부일씨앤디 retry: 5
# 옛삼덕수타면 retry: 5
# 가매야 retry: 5
# 차아나플레인 retry: 5
# 장수갈매기 retry: 5
# 해미집 retry: 5
# 올라6(주)호텔올라 retry: 5
# 올라6(주)호텔올라 retry: 4
# 주식회사공바위 retry: 5
# 고려정 retry: 5
# 한서외식산업주식회사(한우리한점) retry: 5
# 창고43시청점 retry: 5
# 광안리부산환집 retry: 5
# 0(1조 retry: 5
# 리틀타이 retry: 5
# 스타벅스(서여의도) retry: 5
# (주)블랙스톤리조트양평 retry: 5
# 한화호텔앤드리조트(의원식당) retry: 5
# 행복의강 retry: 5
# 신씨화로신촌점 retry: 5
# 오늘은재영이네가 retry: 5
# 국회후생복지(커피숍) retry: 5
# 백리향(63빌딩) retry: 5
# 김박사손칼국수 retry: 5
# 돌산산장 retry: 5
# 삼송 retry: 5
# 금호횟집 retry: 5
# 호텔농심 retry: 5
# 호메로스호텔 retry: 5
# 해주냉면 retry: 5
# 주례한우갈비 retry: 5
# 어부횟집 retry: 5
# 향촌돼지국밥 retry: 5
# 여울돈단지 retry: 5
# 홍문 retry: 5
# 리안유통 retry: 5
# 구통성 retry: 5
# 노이프레소커피 retry: 5
# 마산식당 retry: 5
# 마산식당 retry: 4
# 한상바다 retry: 5
# 농업회사법인(주)대성축산물직판장 retry: 5
# 양평(하)휴게소탐앤탐스 retry: 5
# 땀뽕 retry: 5
# 제일면제소 retry: 5
# 자성화코다리 retry: 5
# 진사골순대국설렁탕 retry: 5
# 세프의국수전 retry: 5
# 월향조선횟집 retry: 5
# 한길식당 retry: 5
# 정읍(논산)휴게소 retry: 5
# 용인(강릉)휴게소 retry: 5
# 주식회사설풍 retry: 5
# 바다호텔 retry: 5
# 광명동편맞이방일반음코에레일유통 retry: 5
# 대가24시간순대국 retry: 5
# 한촌탕반명가 retry: 5
# 무샤 retry: 5
# 무샤 retry: 4
# 태성골뱅이신사 retry: 5
# 로쏘비앙코 retry: 5
# 탐앤탐스화곡역점 retry: 5
# 스타우동 retry: 5
# 우미각 retry: 5
# 구기돌 retry: 5
# 모던김밥 retry: 5
# 쿠마쿠시 retry: 5
# 한국문화재재단 retry: 5
# 신의주순대와푸꾸미 retry: 5
# ECMD-국회의원식당(본청) retry: 5
# 최군식당 retry: 5
# 소야돼지야-본점 retry: 5
# 샤보텐서여의도점 retry: 5
# 큰집냉면 retry: 5
# 도현농장 retry: 5
# 반구정어부담수 retry: 5
# 시흥감자탕 retry: 5
# 길성이백숙 retry: 5
# 비원한정식 retry: 5
# 정림개발(주) retry: 5
# SK네트웍스(주)워커힐 retry: 5
# 올갱이와청국장 retry: 5
# 달인겉절이칼국수샤브 retry: 5
# 달인겉절이칼국수샤브 retry: 4
# 기소야 retry: 5
# 들이대낙지 retry: 5
# 김포농협감정동지점 retry: 5
# 사람과산 retry: 5
# 원당쇠고기국밥 retry: 5
# 원배추해장국 retry: 5
# 전주콩뿌리콩나물국밥 retry: 5
# 주연생구이 retry: 5
# 북경중화요리 retry: 5
# 서가네우렁쌈밥 retry: 5
# 예스의정부부대찌게 retry: 5
# 신통큰짬뽕 retry: 5
# 김밥천국(종로) retry: 5
# 놀이터 retry: 5
# 청해반북수원점 retry: 5
# 나는바다다 retry: 5
# 투덜이아저씨네쌈밥 retry: 5
# 홍콩반점여의도점 retry: 5
# 초록봉평메밀 retry: 5
# 본돈스(강서) retry: 5
# 두끼비집 retry: 5
# 샤보텐 retry: 5
# 농촌순두부 retry: 5
# 파리크라상(여의도2호) retry: 5
# 생모루 retry: 5
# 구백가든 retry: 5
# 석정수산 retry: 5
# KFC서소문점 retry: 5
# 삼시세끼 retry: 5
# GS25남산힐튼점 retry: 5
# 담소사골순대국 retry: 5
# 나미일식 retry: 5
# 반가 retry: 5
# 장마네키네코 retry: 5
# 일리에스프레스 retry: 5
# 본죽마포공덕점 retry: 5
# 본죽세브란스점 retry: 5
# GS25북창스타점 retry: 5
# 서울목 retry: 5
# 옹팡집한우고깃집 retry: 5
# 세븐일레븐여의알렉스 retry: 5
# 씨유63빌딩점 retry: 5
# GS25광주삼지곡점 retry: 5
# 버드나무 retry: 5
# 승아식당 retry: 5
# 마실한정식 retry: 5
# 황소야인천시청정 retry: 5

# %%
json.dump(place_dict, open('./place_dict.json', 'w'))

# %%
len(place_dict)
# Out:
# 6762

# %%
pd.Series([len(place_dict[place]) for place in place_dict]).value_counts()
# Out:
# 5    2288
# 0    2201
# 1    1367
# 2     470
# 3     247
# 4     189
# dtype: int64

# %%
pd.DataFrame(data={'road_address': '서울특별시 영등포구 국회대로 800 진미파라곤',
  'phone_number': '02-780-0363',
  'x': '126.9213120',
  'y': '37.5309780'}, index=[1])
# Out:
#                 road_address phone_number            x           y
# 1  서울특별시 영등포구 국회대로 800 진미파라곤  02-780-0363  126.9213120  37.5309780

# %%
def place_info(place_name, elem):
    d = place_dict[place_name]
    if len(d) != 1:
        return None
    if elem=='road_address' and d[0][elem]=='':
        elem='jibun_address'
    return d[0][elem]

# %%
x = []
columns = ['road_address','phone_number','x','y']
for c in columns:
    x.append(df['사용처'].apply(place_info, elem=c))

# %%
def place_series(place_name, return_all=False):
    d = place_dict[place_name]
    if len(d) == 0 or \
    ((not return_all) and len(d) > 1): # return that has only one match
        return pd.Series()
    
    addr_column = 'road_address'
    if d[0][addr_column]=='': # some places have no "road address"
        addr_column='jibun_address'
    return_dict = {elem:d[0][elem] for elem in ['phone_number','x','y']}
    return_dict['addr'] = d[0][addr_column]
    return pd.Series(return_dict)

# %%
naver_map_df = df['사용처'].apply(place_series)

# %%
df = pd.concat([df, naver_map_df], axis=1)

# %%
addr_minmax = df[df.notnull()['주소']].groupby(['의원명','사용처']).agg({'주소':[min, max]})
addr_minmax[:5]
# Out:
#                                            주소
#                                           min                        max
# 의원명 사용처
# 강석호 (주)밥보                서욽특별시 영등포구 여의도동 13-3       서욽특별시 영등포구 여의도동 13-3
#     (주)이랜드파크켄싱턴여의도       서울특별시 영등포구 여의도동 13-3       서울특별시 영등포구 여의도동 13-3
#     (주)이와타쇼         서울특별시 영등포구 여의도동 36-2 지하1층  서울특별시 영등포구 여의도동 36-2 지하1층
#     (주)제스코푸드청담지점             서울특별시 강남구 삼성동 88           서울특별시 강남구 삼성동 88
#     (주)조선호텔호무랑              서울특별시 강남구 청담동 4-1          서울특별시 강남구 청담동 4-1

# %%
tmp_df = addr_minmax.droplevel(level=0, axis=1)

# %%
tmp_df[tmp_df['min'] != tmp_df['max']]
# Out:
#                                                 min  \
# 의원명 사용처
# 김성수 (주)커피빈코리아                 경기도 시흥시 산천로 100번안길 16
#     물자리                         서울특별시 종로구 삼봉로 80-10
#     봉명성                            서울특별시 영등포구 74길 9
#     스시설                   경기도 고양시 일산동구 강송로 217번길 73
#     이꾸                        서울특별시 영등포구 국회대로 72길 6
#     정인면옥                     서울특별시 영등포구 국회대로 76길 22
#     진진                  서울특별시 영등포구 국회대로 72길 11 프린스텔
#     차이나플레인                   서울특별시 영등포구 국회대로 72길 11
#     쿠치나후                         서울특별시 영등포구 의사당대로 1
#     파리크라상                         서울특별시 영등포구 74길 12
#     파리크루아상                        서울특별시 영등포구 74길 12
# 노웅래 군산오징어                      서울특별시 강남구 남부순환로 2615
#     양평신내해장국                    서울특별시 마포구 토정로 31길 24
#     지호마포점                         서울특별시 마포구 독막로 229
#     회관직원식당                      서울특별시 마포구 마포대로6길 10
# 서청원 상도갈비타운                          서울시 동작구 상도동 522
# 유승민 삼보정                        서울특별시 영등포구 여의도동 35-5
#     한화호텔앤리조트프레스센터점                서울특별시 중구 세종대로 124
#     향연                         서울특별시 영등포구 여의도동 23-1
# 정우택 노조미             서울특별시 영등포구 여의도동 15-24 삼희익스콘벤처타워
#     차이나프로               서울특별시 영등포구 여의도동 LG트윈타워 동관5층
#
#                                                       max
# 의원명 사용처
# 김성수 (주)커피빈코리아                       경기도 시흥시 신천로 100번안길 16
#     물자리                               서울특별시 종로구 상봉로 80-10
#     봉명성                             서울특별시 영등포구 국회대로 74길 9
#     스시설                          경기도 고양시 일산동구 강송로217번길 73
#     이꾸                               서울특별시 영등포구 국회대로72길 6
#     정인면옥                          서울특별시 영등포구 국회대로 76번길 22
#     진진                             서울특별시 영등포구 국회대로 76길 11
#     차이나플레인                           서울특별시 영등포구 여의도동 13-3
#     쿠치나후                            서울특별시 영등포구 의사당대로1 의정관
#     파리크라상                          서울특별시 영등포구 국회대로 74길 12
#     파리크루아상                         서울특별시 영등포구 국회대로 74길 12
# 노웅래 군산오징어                          서울특별시 마포구 마포대로 14가길 18
#     양평신내해장국                           서울특별시 마포구 토정로31길 24
#     지호마포점                           서울특별시 영등포구 국회대로74길 19
#     회관직원식당                             서울특별시 영등포구 의사당대로 1
# 서청원 상도갈비타운                              서울특별시 동작구 상도동 522
# 유승민 삼보정                         서울특별시 영등포구 여의도동 35-5 종합상가
#     한화호텔앤리조트프레스센터점                       서울특별시 중구 세종대로124
#     향연                              서울특별시 종로구 사직로 10길 9-6
# 정우택 노조미             서울특별시 영등포구 여의도동 15-24 삼희익스콘벤처타워 B113호
#     차이나프로                        서울특별시 영등포구 여의도동 맨하탄빌딩 1층

# %%
df.query("주소>'' and addr>''")
# Out:
#              총연번  의원번호  의원명       당   당ID              지역명         연월일  \
# 351    17_001581     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군    2017.2.7
# 356    17_001591     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.2.13
# 360    17_001609     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.2.20
# 363    17_001619     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.2.22
# 378    17_001680     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.3.29
# 379    17_001681     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.3.29
# 382    17_001692     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군    2017.4.6
# 384    17_001697     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.4.11
# 387    17_001701     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.4.12
# 393    17_001717     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.4.18
# 402    17_001795     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.5.22
# 405    17_001838     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.6.16
# 407    17_001840     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.6.16
# 410    17_001846     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.6.20
# 422    17_001955     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진군   2017.9.11
# 444    17_002071     5  강석호   자유한국당   200  경북 영양군영덕군봉화군울진
# 17145                  정책협의관련티타임비   88,000   신라스테이역삼카페    간담회_다과
# 17146                  기관협의관련간담회비  260,000         코마찌    간담회_식대
# 17156                  기관협의관련간담회비  318,000       차이나프로    간담회_식대
# 17158                  정책협의관련간담회비  943,000      키사라여의도    간담회_식대
# 17176                  기관협의관련간담회비  241,000       차이나프로    간담회_식대
# 17180                  정책협의관련간담회비  541,000       차이나프로    간담회_식대
# 17194                  정책협의관련간담회비  203,000       미당한정식    간담회_식대
# 17210                  정책협의관련간담회비  330,500      키사라여의도    간담회_식대
# 17219                  정책협의관련티타임비  381,000        쿠치나후    간담회_다과
# 17223                  정책협의관련간담회비  282,000       서초삿뽀로    간담회_식대
# 17227                  정책협의관련간담회비  375,000       차이나프로    간담회_식대
# 17233                  정책협의관련간담회비  460,000      키사라여의도    간담회_식대
# 17237                  정책협의관련간담회비  162,000      키사라여의도    간담회_식대
# 17239                  정책협의관련간담회비  206,000       차이나프로    간담회_식대
# 17244                  정책협의관련간담회비  184,000      키사라여의도    간담회_식대
# 17247                  기관협의관련간담회비  123,000       차이나프로    간담회_식대
# 17254                  정책협의관련간담회비  283,000       차이나프로    간담회_식대
# 17260                  정책협의관련간담회비  146,000       차이나프로    간담회_식대
# 17264                  정책협의관련간담회비  522,000       차이나프로    간담회_식대
# 17268                  정책협의관련간담회비  319,000       차이나프로    간담회_식대
# 17272                  기관협의관련간담회비  247,000       차이나프로    간담회_식대
# 17275                  기관협의관련간담회비  329,000      키사라여의도    간담회_식대
# 17277                  기관협의관련간담회비  513,500       차이나프로    간담회_식대
# 17279                  정책협의관련간담회비  426,000       차이나프로    간담회_식대
# 17284                  기관협의관련간담회비  535,000    창고43VIP점    간담회_식대
#
#                                 주소  의원지출액순위 Unnamed: 13  phone_number  \
# 351        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 356        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 360            서울특별시 영등포구 국회대로 780        4         NaN   02-783-6409
# 363        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 378           서울특별시 영등포구 여의도동 23-7        4         NaN  032-620-5690
# 379           서울특별시 영등포구 여의도동 23-7        4         NaN  032-620-5690
# 382             서울특별시 영등포구 여의도동 36        4         NaN   02-780-6030
# 384        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 387           서울특별시 영등포구 여의도동 23-7        4         NaN  032-620-5690
# 393               경상남도 진주시 대안동 4-1        4         NaN  055-741-2646
# 402           서울특별시 영등포구 여의도동 23-7        4         NaN  032-620-5690
# 405              서울특별시 영등포구 63로 50        4         NaN   02-789-5751
# 407          서울특별시 영등포구 의사당대로1길 11        4         NaN   02-783-5724
# 410             서울특별시 영등포구 여의도동 36        4         NaN   02-780-6030
# 422        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 444      서울특별시 영등포구 의사당대로 1 의정관 6층        4         NaN  02-3775-3634
# 446        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 452        서울특별시 영등포구 여의도동 16-2 1층        4         NaN   02-761-4997
# 456      서울특별시 영등포구 의사당대로 1 의정관 6층        4         NaN  02-3775-3634
# 2700         서울특별시 영등포구 의사당대로1 의정관        6         NaN  02-3775-3634
# 2701         서울특별시 영등포구 의사당대로1 의정관        6         NaN  02-3775-3634
# 2709         서울특별시 영등포구 의사당대로1 의정관        6         NaN  02-3775-3634
# 2712          서울특별시 마포구 토정로 25길 43        6         NaN  02-6404-1989
# 2716           경기도 고양시 일산동구 강송로 33        6         NaN
# 2717        서울특별시 영등포구 국회대로 62길 25        6         NaN   02-780-5292
# 2719            서울특별시 종로구 사간동 62-1        6         NaN   02-722-7003
# 2724            서울특별시 영등포구 의사당대로 1        6         NaN  02-3775-3634
# 2725    경기도 고양시 일산동구 마두동 999-4 8-6        6         NaN  031-923-9913
# 2727        서울특별시 영등포구 국회대로 62길 25        6         NaN   02-780-5292
# 2730            서울특별시 종로구 사간동 62-1        6         NaN   02-722-7003
# ...                            ...      ...         ...           ...
# 11713         서울특별시 마포구 서교동 343-11        2         NaN   02-324-0978
# 11715         서울특별시 마포구 서교동 343-11        2         NaN   02-324-0978
# 11719         서울특별시 마포구 서교동 343-11        2         NaN   02-324-0978
# 17120     서울특별시 영등포구 여의도동 맨하탄빌딩 1층        1         NaN   02-783-0150
# 17135     서울특별시 영등포구 여의도동 맨하탄빌딩 1층        1         NaN   02-783-0150
# 17145            서울특별시 강남구 언주로 517        1         NaN  02-2054-9107
# 17146        서울특별시 광진구 아차산로 76길 19        1         NaN   02-452-2336
# 17156     서울특별시 영등포구 여의도동 맨하탄빌딩 1층        1         NaN   02-783-0150
# 17158  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN  02-3773-1252
# 17176  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17180  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17194            서울특별시 종로구 경희궁1길 6        1         NaN  041-362-1500
# 17210  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN  02-3773-1252
# 17219           서울특별시 영등포구 의사당대로 1        1         NaN  02-3775-3634
# 17223          서울특별시 서초구 서초중앙로 195        1         NaN  02-3477-5544
# 17227  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17233  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN  02-3773-1252
# 17237  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN  02-3773-1252
# 17239  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17244  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN  02-3773-1252
# 17247  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17254  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17260  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17264  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17268  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17272  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17275  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN  02-3773-1252
# 17277  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17279  서울특별시 영등포구 여의도동 LG트윈타워 동관5층        1         NaN   02-783-0150
# 17284      서울특별시 영등포구 국회대로70길 15-1        1         NaN   02-785-2992
#
#                  x           y                                  addr
# 351    126.9226925  37.5281688             서울특별시 영등포구 은행로 30 중소기업중앙회
# 356    126.9226925  37.5281688             서울특별시 영등포구 은행로 30 중소기업중앙회
# 360    126.9191480  37.5299082  서울특별시 영등포구 국회대로 780 엘지에클라트오피스텔 B105호
# 363    126.9226925  37.5281688             서울특별시 영등포구 은행로 30 중소기업중앙회
# 378    126.7785336  37.4970566                       경기도 부천시 신흥로 150
# 379    126.7785336  37.4970566                       경기도 부천시 신흥로 150
# 382    126.9264116  37.5201766                  서울특별시 영등포구 의사당대로 127
# 384    126.9226925  37.5281688             서울특별시 영등포구 은행로 30 중소기업중앙회
# 387    126.7785336  37.4970566                       경기도 부천시 신흥로 150
# 393    128.0844789  35.1961301                   경상남도 진주시 촉석로207번길 3
# 402    126.7785336  37.4970566                       경기도 부천시 신흥로 150
